# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

# Math case error. must be lowercase 'math'

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()

# ans => x being modified inside function.

# %%
#3.
x = 5
if x = 10:
    print("x is 10")

# error: assignment inplace of relational operator

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

# sort() modifies the list returns None.

# %%
# 5.
def square(n):
    n * n


print(square(4))

# nothing will be printed as the function returns nothing

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

# error. tuple is immutable

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# total argument values missing. expected 2 but given 1

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# error. 'is' checks for object identity, not value equality.

# %%
#9.
for i in range(5, 1):
    print(i)

# range(5, 1) does not produce any numbers because the default step is +1

# %%
# 10.
student = {"name": "John", "age": 20}
print(student[name])

# The key should be a string, but name is not defined as a variable.
