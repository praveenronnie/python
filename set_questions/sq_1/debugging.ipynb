# %%
"""
#1.Find the error in the following Python code:

 for i in range(5)
    print(i)
"""

# Corrected code:

for i in range(5):
    print(i)

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)
 
 
#Answer: Error – cannot concatenate integer and string.
a = 10
b = "5"

# solution -> print(a + int(b))

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b)
    return a + b

#Answer: Missing colon : after (a, b)
def add_numbers(a, b):
    return a + b

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers[4])

# Answer: IndexError – list index out of range.

# %%
#5.Find the error in the following Python code:
# print "Hello, World!"

# Ans -> syntaxerror. missing paranthesis for print() method

# %%
#6.Find the error in the following Python code:
x = 5 / 0

# ans -> arithmetic error. cannot divide by 0

# %%
#7.Find the error in the following Python code:name = "Alice"
age = 25
print("Name: " + name + ", Age: " + age)

# ans => cannot concate string with integer

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# ans => step value -1 is incorrect

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")


# ans => syntax error. assignment inplace of relational operator

# %%
#10. Identify the error in the following function definition:

def greet(name)
    print("Hello, " + name)


# ans => missing colon after function definition
